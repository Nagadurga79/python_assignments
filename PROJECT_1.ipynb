# %%
import pandas as pd
import numpy as np

# %%
# ----------import bbb patients
bbb_patients_df=pd.read_excel(r"C:\Users\hp\Downloads\Insurance_Customers.xlsx",sheet_name="BBB_Patients")

# %%
bbb_patients_df
# Out:
#        patientid  membershid    groupid   person_nbr
# 0          10001   123456891  Upperbody  2386.041022
# 1          10002   123456891  Upperbody  7219.568003
# 2          10003   123456891  Upperbody  1110.167181
# 3          10004   123456891  Upperbody  4522.639998
# 4          10005   123456891  Upperbody  7305.192980
# ...          ...         ...        ...          ...
# 10114      20115   123456896     Nerves  2985.574310
# 10115      20116   123456896     Nerves  9698.888692
# 10116      20117   123456896     Nerves  3305.456074
# 10117      20118   123456896     Nerves  9179.853623
# 10118      20119   123456896     Nerves  2048.429434
#
# [10119 rows x 4 columns]

# %%
# ---------basic chekings
bbb_patients_df.head()
# Out:
#    patientid  membershid    groupid   person_nbr
# 0      10001   123456891  Upperbody  2386.041022
# 1      10002   123456891  Upperbody  7219.568003
# 2      10003   123456891  Upperbody  1110.167181
# 3      10004   123456891  Upperbody  4522.639998
# 4      10005   123456891  Upperbody  7305.192980

# %%
bbb_patients_df.tail()
# Out:
#        patientid  membershid groupid   person_nbr
# 10114      20115   123456896  Nerves  2985.574310
# 10115      20116   123456896  Nerves  9698.888692
# 10116      20117   123456896  Nerves  3305.456074
# 10117      20118   123456896  Nerves  9179.853623
# 10118      20119   123456896  Nerves  2048.429434

# %%
bbb_patients_df.shape
# Out:
# (10119, 4)

# %%
bbb_patients_df.columns
# Out:
# Index(['patientid', 'membershid', 'groupid', 'person_nbr'], dtype='object')

# %%
bbb_patients_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10119 entries, 0 to 10118
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   patientid   10119 non-null  int64
#  1   membershid  10119 non-null  int64
#  2   groupid     10119 non-null  object
#  3   person_nbr  10119 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 316.3+ KB

# %%
# -------import bbb address
bbb_address_df=pd.read_excel(r"C:\Users\hp\Downloads\Insurance_Customers.xlsx",sheet_name="BBB_Address")

# %%
bbb_address_df
# Out:
#        patientid  membershid    groupid    person_nbr Primary_Phone_NBR  \
# 0          10001   123456891  Upperbody  2.386041e+03                 C
# 1          10002   123456891  Upperbody  7.219568e+03                 C
# 2          10003   123456891  Upperbody  1.110167e+03                 C
# 3          10004   123456891  Upperbody  4.522640e+03                 C
# 4          10005   123456891  Upperbody  7.305193e+03                 C
# ...          ...         ...        ...           ...               ...
# 15989      25990    28862324       EarD  6.265158e+06                 C
# 15990      25991    46570001       EarD  5.130131e+06                 C
# 15991      25992    26399463       EarD  6.256841e+06                 C
# 15992      25993    63512490       EarD  2.566051e+06                 C
# 15993      25994    30518036       EarD  1.034701e+07                 C
#
#       Phone2_NBR Phone3_NBR
# 0              O          C
# 1              O          C
# ...

# %%
#-------------basic chakings
bbb_address_df.head()
# Out:
#    patientid  membershid    groupid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0      10001   123456891  Upperbody  2386.041022                 C          O
# 1      10002   123456891  Upperbody  7219.568003                 C          O
# 2      10003   123456891  Upperbody  1110.167181                 C          O
# 3      10004   123456891  Upperbody  4522.639998                 C          O
# 4      10005   123456891  Upperbody  7305.192980                 C          O
#
#   Phone3_NBR
# 0          C
# 1          C
# 2          C
# 3          C
# 4          C

# %%
bbb_address_df.tail()
# Out:
#        patientid  membershid groupid    person_nbr Primary_Phone_NBR  \
# 15989      25990    28862324    EarD  6.265158e+06                 C
# 15990      25991    46570001    EarD  5.130131e+06                 C
# 15991      25992    26399463    EarD  6.256841e+06                 C
# 15992      25993    63512490    EarD  2.566051e+06                 C
# 15993      25994    30518036    EarD  1.034701e+07                 C
#
#       Phone2_NBR Phone3_NBR
# 15989          H          C
# 15990          H          C
# 15991          H          C
# 15992          H          C
# 15993          H          C

# %%
bbb_address_df.shape
# Out:
# (15994, 7)

# %%
bbb_address_df.columns
# Out:
# Index(['patientid', 'membershid', 'groupid', 'person_nbr', 'Primary_Phone_NBR',
#        'Phone2_NBR', 'Phone3_NBR'],
#       dtype='object')

# %%
# jions patients and address(base_patients)
bbb_P_A_merge=bbb_patients_df.merge(bbb_address_df,how="left",on=['patientid', 'membershid', 'groupid', 'person_nbr'])
bbb_P_A_merge
# Out:
#        patientid  membershid    groupid   person_nbr Primary_Phone_NBR  \
# 0          10001   123456891  Upperbody  2386.041022                 C
# 1          10002   123456891  Upperbody  7219.568003                 C
# 2          10003   123456891  Upperbody  1110.167181                 C
# 3          10004   123456891  Upperbody  4522.639998                 C
# 4          10005   123456891  Upperbody  7305.192980                 C
# ...          ...         ...        ...          ...               ...
# 10114      20115   123456896     Nerves  2985.574310                 C
# 10115      20116   123456896     Nerves  9698.888692                 C
# 10116      20117   123456896     Nerves  3305.456074                 C
# 10117      20118   123456896     Nerves  9179.853623                 C
# 10118      20119   123456896     Nerves  2048.429434                 C
#
#       Phone2_NBR Phone3_NBR
# 0              O          C
# 1              O          C
# ...

# %%
bbb_P_A_merge.head()
# Out:
#    patientid  membershid    groupid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0      10001   123456891  Upperbody  2386.041022                 C          O
# 1      10002   123456891  Upperbody  7219.568003                 C          O
# 2      10003   123456891  Upperbody  1110.167181                 C          O
# 3      10004   123456891  Upperbody  4522.639998                 C          O
# 4      10005   123456891  Upperbody  7305.192980                 C          O
#
#   Phone3_NBR
# 0          C
# 1          C
# 2          C
# 3          C
# 4          C

# %%
bbb_P_A_merge.tail()
# Out:
#        patientid  membershid groupid   person_nbr Primary_Phone_NBR  \
# 10114      20115   123456896  Nerves  2985.574310                 C
# 10115      20116   123456896  Nerves  9698.888692                 C
# 10116      20117   123456896  Nerves  3305.456074                 C
# 10117      20118   123456896  Nerves  9179.853623                 C
# 10118      20119   123456896  Nerves  2048.429434                 C
#
#       Phone2_NBR Phone3_NBR
# 10114          H          C
# 10115          H          C
# 10116          H          C
# 10117          H          C
# 10118          H          C

# %%
#-------create cell_flag
bbb_P_A_merge["cell_Flag"]=""

# %%
bbb_P_A_merge.head()
# Out:
#    patientid  membershid    groupid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0      10001   123456891  Upperbody  2386.041022                 C          O
# 1      10002   123456891  Upperbody  7219.568003                 C          O
# 2      10003   123456891  Upperbody  1110.167181                 C          O
# 3      10004   123456891  Upperbody  4522.639998                 C          O
# 4      10005   123456891  Upperbody  7305.192980                 C          O
#
#   Phone3_NBR cell_Flag
# 0          C
# 1          C
# 2          C
# 3          C
# 4          C

# %%
# ---p update in cell flag where pr=c
bbb_P_A_merge["cell_Flag"]=np.where(bbb_P_A_merge["Primary_Phone_NBR"]=="C","P",bbb_P_A_merge["cell_Flag"])

# %%
bbb_P_A_merge.head()
# Out:
#    patientid  membershid    groupid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0      10001   123456891  Upperbody  2386.041022                 C          O
# 1      10002   123456891  Upperbody  7219.568003                 C          O
# 2      10003   123456891  Upperbody  1110.167181                 C          O
# 3      10004   123456891  Upperbody  4522.639998                 C          O
# 4      10005   123456891  Upperbody  7305.192980                 C          O
#
#   Phone3_NBR cell_Flag
# 0          C         P
# 1          C         P
# 2          C         P
# 3          C         P
# 4          C         P

# %%
# ---cell flag update for S flag where prime number!=c, pr2=c 
bbb_P_A_merge["cell_Flag"]=np.where((bbb_P_A_merge["Primary_Phone_NBR"]!="C")&(bbb_P_A_merge["Phone2_NBR"]=="C"),"S",bbb_P_A_merge["cell_Flag"])

# %%
# ---cell flag update for S flag where prime number!=c , pr3=c
bbb_P_A_merge["cell_Flag"]=np.where((bbb_P_A_merge["Primary_Phone_NBR"]!="C")&(bbb_P_A_merge["Phone3_NBR"]=="C"),"S",bbb_P_A_merge["cell_Flag"])

# %%
# ---cell flag update for N flag where prime number!=c pr2!=c 
bbb_P_A_merge["cell_Flag"]=np.where((bbb_P_A_merge["Primary_Phone_NBR"]!="C")&(bbb_P_A_merge["Phone2_NBR"]!="C"),"N",bbb_P_A_merge["cell_Flag"])

# %%
# ---cell flag update for N flag where prime number!=c  or pr3!=c
bbb_P_A_merge["cell_Flag"]=np.where((bbb_P_A_merge["Primary_Phone_NBR"]!="C")&(bbb_P_A_merge["Phone3_NBR"]!="C"),"N",bbb_P_A_merge["cell_Flag"])

# %%
bbb_P_A_merge.cell_Flag.unique()
# Out:
# array(['P', 'N', 'S'], dtype=object)

# %%
# value counts
bbb_P_A_merge.cell_Flag.value_counts()
# Out:
# N    6371
# P    3747
# S       1
# Name: cell_Flag, dtype: int64

# %%
# flag update
bbb_P_A_merge['Flag']="Total BBB patients"

# %%
bbb_P_A_merge.head()
# Out:
#    patientid  membershid    groupid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0      10001   123456891  Upperbody  2386.041022                 C          O
# 1      10002   123456891  Upperbody  7219.568003                 C          O
# 2      10003   123456891  Upperbody  1110.167181                 C          O
# 3      10004   123456891  Upperbody  4522.639998                 C          O
# 4      10005   123456891  Upperbody  7305.192980                 C          O
#
#   Phone3_NBR cell_Flag                Flag
# 0          C         P  Total BBB patients
# 1          C         P  Total BBB patients
# 2          C         P  Total BBB patients
# 3          C         P  Total BBB patients
# 4          C         P  Total BBB patients

# %%
# update in flag total BBB patients for cell_flag p
bbb_p_A_merge_P=bbb_P_A_merge[bbb_P_A_merge.cell_Flag=="P"]

# %%
bbb_p_A_merge_P['Flag']="total BBB patients with cell_Flag p "
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\4128734653.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbb_p_A_merge_P['Flag']="total BBB patients with cell_Flag p "

# %%
bbb_p_A_merge_P
# Out:
#        patientid  membershid    groupid   person_nbr Primary_Phone_NBR  \
# 0          10001   123456891  Upperbody  2386.041022                 C
# 1          10002   123456891  Upperbody  7219.568003                 C
# 2          10003   123456891  Upperbody  1110.167181                 C
# 3          10004   123456891  Upperbody  4522.639998                 C
# 4          10005   123456891  Upperbody  7305.192980                 C
# ...          ...         ...        ...          ...               ...
# 10114      20115   123456896     Nerves  2985.574310                 C
# 10115      20116   123456896     Nerves  9698.888692                 C
# 10116      20117   123456896     Nerves  3305.456074                 C
# 10117      20118   123456896     Nerves  9179.853623                 C
# 10118      20119   123456896     Nerves  2048.429434                 C
#
#       Phone2_NBR Phone3_NBR cell_Flag                                  Flag
# ...

# %%
#update in flag total BBB patients for cell_Flag S 
bbb_p_A_merge_S=bbb_P_A_merge[bbb_P_A_merge.cell_Flag=="S"]

# %%
bbb_p_A_merge_S["Flag"]="total BBB patients with cell_Flag S"
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\3313615230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbb_p_A_merge_S["Flag"]="total BBB patients with cell_Flag S"

# %%
bbb_p_A_merge_S
# Out:
#       patientid  membershid  groupid   person_nbr Primary_Phone_NBR  \
# 7117      17118   123456895  Obesity  1969.190691                 O
#
#      Phone2_NBR Phone3_NBR cell_Flag                                 Flag
# 7117          C          C         S  total BBB patients with cell_Flag S

# %%
# update in flag total BBB for cell flag N
bbb_p_A_merge_N=bbb_P_A_merge[bbb_P_A_merge.cell_Flag=="N"]

# %%
bbb_p_A_merge_N["Flag"]="total BBB patients with cell_Flag N"
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\1948260465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbb_p_A_merge_N["Flag"]="total BBB patients with cell_Flag N"

# %%
bbb_p_A_merge_N
# Out:
#       patientid  membershid    groupid   person_nbr Primary_Phone_NBR  \
# 614       10615   123456891  Lowerbody  3303.046210                 O
# 615       10616   123456891  Lowerbody  4080.627852                 O
# 616       10617   123456891  Lowerbody  4888.358478                 O
# 617       10618   123456891  Lowerbody  9764.582779                 O
# 618       10619   123456891  Lowerbody  7557.726735                 O
# ...         ...         ...        ...          ...               ...
# 7187      17188   123456895    Obesity  9565.025227                 O
# 7188      17189   123456895    Obesity  4904.301854                 O
# 7189      17190   123456895    Obesity  1480.185813                 O
# 7190      17191   123456895    Obesity  4421.445047                 O
# 7191      17192   123456895    Obesity  8054.137283                 O
#
#      Phone2_NBR Phone3_NBR cell_Flag                                 Flag
# ...

# %%
#bbb_P_A_merge,bbb_p_A_merge_P,bbb_p_A_merge_S,bbb_p_A_merge_N

# %%
#  data frame create and bbb patients count 
bbb_P_A_merge_sum=bbb_P_A_merge.groupby(["Flag"])["patientid"].count()
bbb_P_A_merge_sum_ndf=pd.DataFrame(bbb_P_A_merge_sum)
bbb_P_A_merge_sum_ndf.reset_index(inplace=True)

# %%
bbb_P_A_merge_sum_ndf
# Out:
#                  Flag  patientid
# 0  Total BBB patients      10119

# %%
#  data frame create and p patients count 
bbb_p_A_merge_P_sum=bbb_p_A_merge_P.groupby(["Flag"])["patientid"].count()
bbb_p_A_merge_P_sum_ndf=pd.DataFrame(bbb_p_A_merge_P_sum)
bbb_p_A_merge_P_sum_ndf.reset_index(inplace=True)

# %%
bbb_p_A_merge_P_sum_ndf
# Out:
#                                    Flag  patientid
# 0  total BBB patients with cell_Flag p        3747

# %%
# data frame create and S patients count
bbb_p_A_merge_S_sum=bbb_p_A_merge_S.groupby(["Flag"])["patientid"].count()
bbb_p_A_merge_S_sum_ndf=pd.DataFrame(bbb_p_A_merge_S_sum)
bbb_p_A_merge_S_sum_ndf.reset_index(inplace=True)

# %%
bbb_p_A_merge_S_sum_ndf
# Out:
#                                   Flag  patientid
# 0  total BBB patients with cell_Flag S          1

# %%
# data frame create and N patients count
bbb_p_A_merge_N_sum=bbb_p_A_merge_N.groupby(["Flag"])["patientid"].count()
bbb_p_A_merge_N_sum_ndf=pd.DataFrame(bbb_p_A_merge_N_sum)
bbb_p_A_merge_N_sum_ndf.reset_index(inplace=True)

# %%
bbb_p_A_merge_N_sum_ndf
# Out:
#                                   Flag  patientid
# 0  total BBB patients with cell_Flag N       6371

# %%
dataframe1=pd.concat([bbb_P_A_merge_sum_ndf,bbb_p_A_merge_P_sum_ndf,bbb_p_A_merge_S_sum_ndf,bbb_p_A_merge_N_sum_ndf],axis=0,ignore_index=True)

# %%
dataframe1.columns=["Flag","Count"]

# %%
# date
from datetime import date
date=date.today()
print(date)
# Out:
# 2023-11-10

# %%
import time
today=time.localtime()
t=time.strftime("%H:%M:%S",today)
print(t)
# Out:
# 00:42:08

# %%
dataframe1["Date"]=date

# %%
dataframe1["Time"]=t

# %%
dataframe1
# Out:
#                                    Flag  Count        Date      Time
# 0                    Total BBB patients  10119  2023-11-10  00:42:08
# 1  total BBB patients with cell_Flag p    3747  2023-11-10  00:42:08
# 2   total BBB patients with cell_Flag S      1  2023-11-10  00:42:08
# 3   total BBB patients with cell_Flag N   6371  2023-11-10  00:42:08

# %%
# jions patients and address(base_patients) with 3 columns
bbb_P_A_merge=bbb_patients_df.merge(bbb_address_df,how="left",on=['patientid', 'membershid', 'groupid'])
bbb_P_A_merge
# Out:
#        patientid  membershid    groupid  person_nbr_x  person_nbr_y  \
# 0          10001   123456891  Upperbody   2386.041022   2386.041022
# 1          10002   123456891  Upperbody   7219.568003   7219.568003
# 2          10003   123456891  Upperbody   1110.167181   1110.167181
# 3          10004   123456891  Upperbody   4522.639998   4522.639998
# 4          10005   123456891  Upperbody   7305.192980   7305.192980
# ...          ...         ...        ...           ...           ...
# 10114      20115   123456896     Nerves   2985.574310   2985.574310
# 10115      20116   123456896     Nerves   9698.888692   9698.888692
# 10116      20117   123456896     Nerves   3305.456074   3305.456074
# 10117      20118   123456896     Nerves   9179.853623   9179.853623
# 10118      20119   123456896     Nerves   2048.429434   2048.429434
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR
# 0                     C          O          C
# 1                     C          O          C
# ...

# %%
# create cell flag 
bbb_P_A_merge["cell_Flag"]=""
bbb_P_A_merge
# Out:
#        patientid  membershid    groupid  person_nbr_x  person_nbr_y  \
# 0          10001   123456891  Upperbody   2386.041022   2386.041022
# 1          10002   123456891  Upperbody   7219.568003   7219.568003
# 2          10003   123456891  Upperbody   1110.167181   1110.167181
# 3          10004   123456891  Upperbody   4522.639998   4522.639998
# 4          10005   123456891  Upperbody   7305.192980   7305.192980
# ...          ...         ...        ...           ...           ...
# 10114      20115   123456896     Nerves   2985.574310   2985.574310
# 10115      20116   123456896     Nerves   9698.888692   9698.888692
# 10116      20117   123456896     Nerves   3305.456074   3305.456074
# 10117      20118   123456896     Nerves   9179.853623   9179.853623
# 10118      20119   123456896     Nerves   2048.429434   2048.429434
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR cell_Flag
# 0                     C          O          C
# 1                     C          O          C
# ...

# %%
# checking columns 
bbb_P_A_merge.columns
# Out:
# Index(['patientid', 'membershid', 'groupid', 'person_nbr_x', 'person_nbr_y',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR', 'cell_Flag'],
#       dtype='object')

# %%
# filter unwanted columns
BBB_fil=bbb_P_A_merge[['patientid', 'membershid', 'groupid', 'person_nbr_x', 
       'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR', 'cell_Flag']]

# %%
BBB_fil.head()
# Out:
#    patientid  membershid    groupid  person_nbr_x Primary_Phone_NBR  \
# 0      10001   123456891  Upperbody   2386.041022                 C
# 1      10002   123456891  Upperbody   7219.568003                 C
# 2      10003   123456891  Upperbody   1110.167181                 C
# 3      10004   123456891  Upperbody   4522.639998                 C
# 4      10005   123456891  Upperbody   7305.192980                 C
#
#   Phone2_NBR Phone3_NBR cell_Flag
# 0          O          C
# 1          O          C
# 2          O          C
# 3          O          C
# 4          O          C

# %%
# p update in cell flag
BBB_fil["cell_Flag"]=np.where(BBB_fil["Primary_Phone_NBR"]=="C","P",BBB_fil["cell_Flag"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\815588046.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_fil["cell_Flag"]=np.where(BBB_fil["Primary_Phone_NBR"]=="C","P",BBB_fil["cell_Flag"])

# %%
BBB_fil.head()
# Out:
#    patientid  membershid    groupid  person_nbr_x Primary_Phone_NBR  \
# 0      10001   123456891  Upperbody   2386.041022                 C
# 1      10002   123456891  Upperbody   7219.568003                 C
# 2      10003   123456891  Upperbody   1110.167181                 C
# 3      10004   123456891  Upperbody   4522.639998                 C
# 4      10005   123456891  Upperbody   7305.192980                 C
#
#   Phone2_NBR Phone3_NBR cell_Flag
# 0          O          C         P
# 1          O          C         P
# 2          O          C         P
# 3          O          C         P
# 4          O          C         P

# %%
# cell flag update for s where prmnum !=C and pr2= C
BBB_fil["cell_Flag"]=np.where((BBB_fil["Primary_Phone_NBR"]!="C")&(BBB_fil["Phone2_NBR"]=="C"),"S",BBB_fil["cell_Flag"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\2781193176.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_fil["cell_Flag"]=np.where((BBB_fil["Primary_Phone_NBR"]!="C")&(BBB_fil["Phone2_NBR"]=="C"),"S",BBB_fil["cell_Flag"])

# %%
# cell flag update for s where prmnum !=C and pr3= C
BBB_fil["cell_Flag"]=np.where((BBB_fil["Primary_Phone_NBR"]!="C")&(BBB_fil["Phone3_NBR"]=="C"),"S",BBB_fil["cell_Flag"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\2260987614.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_fil["cell_Flag"]=np.where((BBB_fil["Primary_Phone_NBR"]!="C")&(BBB_fil["Phone3_NBR"]=="C"),"S",BBB_fil["cell_Flag"])

# %%
# ---cell flag update for N flag where prime number!=c pr2!=c 
BBB_fil["cell_Flag"]=np.where((BBB_fil["Primary_Phone_NBR"]!="C")&(BBB_fil["Phone2_NBR"]!="C"),"N",BBB_fil["cell_Flag"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\379311699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_fil["cell_Flag"]=np.where((BBB_fil["Primary_Phone_NBR"]!="C")&(BBB_fil["Phone2_NBR"]!="C"),"N",BBB_fil["cell_Flag"])

# %%
# ---cell flag update for N flag where prime number!=c pr3!=c 
BBB_fil["cell_Flag"]=np.where((BBB_fil["Primary_Phone_NBR"]!="C")&(BBB_fil["Phone3_NBR"]!="C"),"N",BBB_fil["cell_Flag"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\309363183.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_fil["cell_Flag"]=np.where((BBB_fil["Primary_Phone_NBR"]!="C")&(BBB_fil["Phone3_NBR"]!="C"),"N",BBB_fil["cell_Flag"])

# %%
BBB_fil.cell_Flag.unique()
# Out:
# array(['P', 'N', 'S'], dtype=object)

# %%
# N,P,S value counts
BBB_fil.cell_Flag.value_counts()
# Out:
# N    6371
# P    3747
# S       1
# Name: cell_Flag, dtype: int64

# %%
BBB_fil["Flag"]="Total BBB patients "

# %%
BBB_fil.head()
# Out:
#    patientid  membershid    groupid  person_nbr_x Primary_Phone_NBR  \
# 0      10001   123456891  Upperbody   2386.041022                 C
# 1      10002   123456891  Upperbody   7219.568003                 C
# 2      10003   123456891  Upperbody   1110.167181                 C
# 3      10004   123456891  Upperbody   4522.639998                 C
# 4      10005   123456891  Upperbody   7305.192980                 C
#
#   Phone2_NBR Phone3_NBR cell_Flag                 Flag
# 0          O          C         P  Total BBB patients
# 1          O          C         P  Total BBB patients
# 2          O          C         P  Total BBB patients
# 3          O          C         P  Total BBB patients
# 4          O          C         P  Total BBB patients

# %%
# update in flag total bbb patients with cell_flag P
BBB_fil_P=BBB_fil[BBB_fil.cell_Flag=="P"]

# %%
BBB_fil_P["Flag"]="Total BBB patients with cell_Flag P"
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\3832052474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_fil_P["Flag"]="Total BBB patients with cell_Flag P"

# %%
BBB_fil_P.head()
# Out:
#    patientid  membershid    groupid  person_nbr_x Primary_Phone_NBR  \
# 0      10001   123456891  Upperbody   2386.041022                 C
# 1      10002   123456891  Upperbody   7219.568003                 C
# 2      10003   123456891  Upperbody   1110.167181                 C
# 3      10004   123456891  Upperbody   4522.639998                 C
# 4      10005   123456891  Upperbody   7305.192980                 C
#
#   Phone2_NBR Phone3_NBR cell_Flag                                 Flag
# 0          O          C         P  Total BBB patients with cell_Flag P
# 1          O          C         P  Total BBB patients with cell_Flag P
# 2          O          C         P  Total BBB patients with cell_Flag P
# 3          O          C         P  Total BBB patients with cell_Flag P
# 4          O          C         P  Total BBB patients with cell_Flag P

# %%
# update in flag total bbb patients with cell_flag s
BBB_fil_S=BBB_fil[BBB_fil.cell_Flag=="S"]

# %%
BBB_fil_S["Flag"]=" Total BBB patients with cell_Flag S"
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\3120904511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_fil_S["Flag"]=" Total BBB patients with cell_Flag S"

# %%
BBB_fil_S
# Out:
#       patientid  membershid  groupid  person_nbr_x Primary_Phone_NBR  \
# 7117      17118   123456895  Obesity   1969.190691                 O
#
#      Phone2_NBR Phone3_NBR cell_Flag                                  Flag
# 7117          C          C         S   Total BBB patients with cell_Flag S

# %%
# update in flag total bbb patients with cell_flag N
BBB_fil_N=BBB_fil[BBB_fil.cell_Flag=="N"]

# %%
BBB_fil_N["Flag"]="Total BBB patients with cell_Flag N "
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\1127397466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BBB_fil_N["Flag"]="Total BBB patients with cell_Flag N "

# %%
BBB_fil_N.head()
# Out:
#      patientid  membershid    groupid  person_nbr_x Primary_Phone_NBR  \
# 614      10615   123456891  Lowerbody   3303.046210                 O
# 615      10616   123456891  Lowerbody   4080.627852                 O
# 616      10617   123456891  Lowerbody   4888.358478                 O
# 617      10618   123456891  Lowerbody   9764.582779                 O
# 618      10619   123456891  Lowerbody   7557.726735                 O
#
#     Phone2_NBR Phone3_NBR cell_Flag                                  Flag
# 614          C          O         N  Total BBB patients with cell_Flag N
# 615          C          O         N  Total BBB patients with cell_Flag N
# 616          C          O         N  Total BBB patients with cell_Flag N
# 617          C          O         N  Total BBB patients with cell_Flag N
# 618          C          O         N  Total BBB patients with cell_Flag N

# %%
BBB_fil_N.Flag.unique()
# Out:
# array(['Total BBB patients with cell_Flag N '], dtype=object)

# %%
# new dataframe create and total bbb patients count
BBB_fil_sum=BBB_fil.groupby(["Flag"])["patientid"].count()
BBB_fil_sum_ndf=pd.DataFrame(BBB_fil_sum)
BBB_fil_sum_ndf.reset_index(inplace=True)

# %%
BBB_fil_sum_ndf
# Out:
#                   Flag  patientid
# 0  Total BBB patients       10119

# %%
# new dataframe create and total bbb patients count
BBB_fil_P_sum=BBB_fil_P.groupby(["Flag"])["patientid"].count()
BBB_fil_P_sum_ndf=pd.DataFrame(BBB_fil_P_sum)
BBB_fil_P_sum_ndf.reset_index(inplace=True)

# %%
BBB_fil_P_sum_ndf
# Out:
#                                   Flag  patientid
# 0  Total BBB patients with cell_Flag P       3747

# %%
# data frame create and N patients count
BBB_fil_N_sum=BBB_fil_N.groupby(["Flag"])["patientid"].count()
BBB_fil_N_sum_ndf=pd.DataFrame(BBB_fil_N_sum)
BBB_fil_N_sum_ndf.reset_index(inplace=True)

# %%
BBB_fil_N_sum_ndf
# Out:
#                                    Flag  patientid
# 0  Total BBB patients with cell_Flag N        6371

# %%
BBB_fil_S_sum=BBB_fil_S.groupby(["Flag"])["patientid"].count()
BBB_fil_S_sum_ndf=pd.DataFrame(BBB_fil_S_sum)
BBB_fil_S_sum_ndf.reset_index(inplace=True)

# %%
BBB_fil_S_sum_ndf
# Out:
#                                    Flag  patientid
# 0   Total BBB patients with cell_Flag S          1

# %%
dataframe2=pd.concat([BBB_fil_sum_ndf,BBB_fil_P_sum_ndf,BBB_fil_S_sum_ndf,BBB_fil_N_sum_ndf],axis=0,ignore_index=True)

# %%
dataframe2.columns=["Flag","Count"]

# %%
#bbb 3 columns dataframe
dataframe2
# Out:
#                                    Flag  Count
# 0                   Total BBB patients   10119
# 1   Total BBB patients with cell_Flag P   3747
# 2   Total BBB patients with cell_Flag S      1
# 3  Total BBB patients with cell_Flag N    6371

# %%
dataframe2["Date"]=date

# %%
dataframe2["Time"]=t

# %%
dataframe2
# Out:
#                                    Flag  Count        Date      Time
# 0                   Total BBB patients   10119  2023-11-10  00:42:08
# 1   Total BBB patients with cell_Flag P   3747  2023-11-10  00:42:08
# 2   Total BBB patients with cell_Flag S      1  2023-11-10  00:42:08
# 3  Total BBB patients with cell_Flag N    6371  2023-11-10  00:42:08

# %%
# time
from datetime import date
date=date.today()
print(date)
# Out:
# 2023-11-10

# %%
import time
today=time.localtime()
t=time.strftime("%H:%M:%S",today)
print(t)
# Out:
# 00:42:08

# %%
#import DDD patients

# %%
DDD_patients_df=pd.read_excel(r"C:\Users\hp\Downloads\Insurance_Customers.xlsx",sheet_name="DDD_Patients")
DDD_patients_df
# Out:
#        patientid    membershid  groupid   person_nbr
# 0         200001   4456.162497      100  2748.280106
# 1         200002   4456.162497      100  3983.633278
# 2         200003   4456.162497      100  5918.043203
# 3         200004   4456.162497      100  5882.418134
# 4         200005   4456.162497      100  3519.095855
# ...          ...           ...      ...          ...
# 84006     284007  61967.640577      108  6406.791285
# 84007     284008  61967.640577      108  5736.801838
# 84008     284009  61967.640577      108  7613.994822
# 84009     284010  61967.640577      108  8530.577571
# 84010     284011  61967.640577      108  2140.830791
#
# [84011 rows x 4 columns]

# %%
#basic checkings
DDD_patients_df.head()
# Out:
#    patientid   membershid  groupid   person_nbr
# 0     200001  4456.162497      100  2748.280106
# 1     200002  4456.162497      100  3983.633278
# 2     200003  4456.162497      100  5918.043203
# 3     200004  4456.162497      100  5882.418134
# 4     200005  4456.162497      100  3519.095855

# %%
DDD_patients_df.tail()
# Out:
#        patientid    membershid  groupid   person_nbr
# 84006     284007  61967.640577      108  6406.791285
# 84007     284008  61967.640577      108  5736.801838
# 84008     284009  61967.640577      108  7613.994822
# 84009     284010  61967.640577      108  8530.577571
# 84010     284011  61967.640577      108  2140.830791

# %%
DDD_patients_df.shape
# Out:
# (84011, 4)

# %%
DDD_patients_df.columns
# Out:
# Index(['patientid', 'membershid', 'groupid', 'person_nbr'], dtype='object')

# %%
#import DDD address
DDD_add_df=pd.read_excel(r"C:\Users\hp\Downloads\Insurance_Customers.xlsx",sheet_name="DDD_Address")
DDD_add_df
# Out:
#        patientid    membershid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR
# 0              O          C
# 1              O          C
# ...

# %%
# ddd patients & ddd address left merge
ddd_P_A_merge=DDD_patients_df.merge(DDD_add_df,how="left",on=["patientid","membershid","groupid","person_nbr"])

# %%
ddd_P_A_merge.head()
# Out:
#    patientid   membershid  groupid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497      100  2748.280106                 C          O
# 1     200002  4456.162497      100  3983.633278                 C          O
# 2     200003  4456.162497      100  5918.043203                 C          O
# 3     200004  4456.162497      100  5882.418134                 C          O
# 4     200005  4456.162497      100  3519.095855                 C          O
#
#   Phone3_NBR
# 0          C
# 1          C
# 2          C
# 3          C
# 4          C

# %%
#import ddd flag
DDD_flag_df=pd.read_excel(r"C:\Users\hp\Downloads\Insurance_Customers.xlsx",sheet_name="DDD_Flag")

# %%
DDD_flag_df
# Out:
#    groupid        Flag
# 0      100        EarD
# 1      102       EyesD
# 2      103     Nervers
# 3      105       KneeF
# 4      106      SpineF
# 5      107     Obesity
# 6      108  Obesity-II

# %%
# ddd patients,add and flag merge
ddd_p_flag_merge=ddd_P_A_merge.merge(DDD_flag_df,how="left",on="groupid")

# %%
ddd_p_flag_merge
# Out:
#        patientid    membershid  groupid   person_nbr Primary_Phone_NBR  \
# 0         200001   4456.162497      100  2748.280106                 C
# 1         200002   4456.162497      100  3983.633278                 C
# 2         200003   4456.162497      100  5918.043203                 C
# 3         200004   4456.162497      100  5882.418134                 C
# 4         200005   4456.162497      100  3519.095855                 C
# ...          ...           ...      ...          ...               ...
# 84006     284007  61967.640577      108  6406.791285                 C
# 84007     284008  61967.640577      108  5736.801838                 C
# 84008     284009  61967.640577      108  7613.994822                 C
# 84009     284010  61967.640577      108  8530.577571                 C
# 84010     284011  61967.640577      108  2140.830791                 C
#
#       Phone2_NBR Phone3_NBR        Flag
# 0              O          C        EarD
# ...

# %%
ddd_p_flag_merge.columns
# Out:
# Index(['patientid', 'membershid', 'groupid', 'person_nbr', 'Primary_Phone_NBR',
#        'Phone2_NBR', 'Phone3_NBR', 'Flag'],
#       dtype='object')

# %%
ddd_p_flag_merge_fil=ddd_p_flag_merge[['patientid', 'membershid', 'person_nbr', 'Primary_Phone_NBR',
       'Phone2_NBR', 'Phone3_NBR', 'Flag']]

# %%
ddd_p_flag_merge_fil.head()
# Out:
#    patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497  2748.280106                 C          O
# 1     200002  4456.162497  3983.633278                 C          O
# 2     200003  4456.162497  5918.043203                 C          O
# 3     200004  4456.162497  5882.418134                 C          O
# 4     200005  4456.162497  3519.095855                 C          O
#
#   Phone3_NBR  Flag
# 0          C  EarD
# 1          C  EarD
# 2          C  EarD
# 3          C  EarD
# 4          C  EarD

# %%
ddd_p_flag_merge_fil.columns=['patientid', 'membershid', 'person_nbr', 'Primary_Phone_NBR',
       'Phone2_NBR', 'Phone3_NBR', 'groupid']

# %%
ddd_p_flag_merge_fil
# Out:
#        patientid    membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0         200001   4456.162497  2748.280106                 C          O
# 1         200002   4456.162497  3983.633278                 C          O
# 2         200003   4456.162497  5918.043203                 C          O
# 3         200004   4456.162497  5882.418134                 C          O
# 4         200005   4456.162497  3519.095855                 C          O
# ...          ...           ...          ...               ...        ...
# 84006     284007  61967.640577  6406.791285                 C          C
# 84007     284008  61967.640577  5736.801838                 C          C
# 84008     284009  61967.640577  7613.994822                 C          C
# 84009     284010  61967.640577  8530.577571                 C          C
# 84010     284011  61967.640577  2140.830791                 C          C
#
#       Phone3_NBR     groupid
# 0              C        EarD
# 1              C        EarD
# ...

# %%
ddd_p_flag_merge_fil["cell_flag"]=""
ddd_p_flag_merge_fil.head()
# Out:
#    patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497  2748.280106                 C          O
# 1     200002  4456.162497  3983.633278                 C          O
# 2     200003  4456.162497  5918.043203                 C          O
# 3     200004  4456.162497  5882.418134                 C          O
# 4     200005  4456.162497  3519.095855                 C          O
#
#   Phone3_NBR groupid cell_flag
# 0          C    EarD
# 1          C    EarD
# 2          C    EarD
# 3          C    EarD
# 4          C    EarD

# %%
ddd_p_flag_merge_fil.columns
# Out:
# Index(['patientid', 'membershid', 'person_nbr', 'Primary_Phone_NBR',
#        'Phone2_NBR', 'Phone3_NBR', 'groupid', 'cell_flag'],
#       dtype='object')

# %%
#cell flag update for P
ddd_p_flag_merge_fil["cell_flag"]=np.where(ddd_p_flag_merge_fil["Primary_Phone_NBR"]=="C","P",ddd_p_flag_merge_fil["cell_flag"])

# %%
ddd_p_flag_merge_fil["cell_flag"]=np.where((ddd_p_flag_merge_fil["Primary_Phone_NBR"]!="C")&(ddd_p_flag_merge_fil["Phone2_NBR"]=="C"),"S",ddd_p_flag_merge_fil["cell_flag"])

# %%
ddd_p_flag_merge_fil["cell_flag"]=np.where((ddd_p_flag_merge_fil["Primary_Phone_NBR"]!="C")&(ddd_p_flag_merge_fil["Phone3_NBR"]=="C"),"S",ddd_p_flag_merge_fil["cell_flag"])

# %%
ddd_p_flag_merge_fil["cell_flag"]=np.where((ddd_p_flag_merge_fil["Primary_Phone_NBR"]!="C")&(ddd_p_flag_merge_fil["Phone2_NBR"]!="C"),"N",ddd_p_flag_merge_fil["cell_flag"])

# %%
ddd_p_flag_merge_fil["cell_flag"]=np.where((ddd_p_flag_merge_fil["Primary_Phone_NBR"]!="C")&(ddd_p_flag_merge_fil["Phone3_NBR"]!="C"),"N",ddd_p_flag_merge_fil["cell_flag"])

# %%
ddd_p_flag_merge_fil.cell_flag.unique()
# Out:
# array(['P', 'N'], dtype=object)

# %%
ddd_p_flag_merge_fil.cell_flag.value_counts()
# Out:
# P    81589
# N     2422
# Name: cell_flag, dtype: int64

# %%
ddd_p_flag_merge_fil['Flag']="Total DDD patients"

# %%
ddd_p_flag_merge_fil.head()
# Out:
#    patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497  2748.280106                 C          O
# 1     200002  4456.162497  3983.633278                 C          O
# 2     200003  4456.162497  5918.043203                 C          O
# 3     200004  4456.162497  5882.418134                 C          O
# 4     200005  4456.162497  3519.095855                 C          O
#
#   Phone3_NBR groupid cell_flag                Flag
# 0          C    EarD         P  Total DDD patients
# 1          C    EarD         P  Total DDD patients
# 2          C    EarD         P  Total DDD patients
# 3          C    EarD         P  Total DDD patients
# 4          C    EarD         P  Total DDD patients

# %%
ddd_p_flag_merge_fil_p=ddd_p_flag_merge_fil[ddd_p_flag_merge_fil.cell_flag=="P"]

# %%
ddd_p_flag_merge_fil_p["Flag"]="Total DDD patients with cell flag P"
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\630790313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddd_p_flag_merge_fil_p["Flag"]="Total DDD patients with cell flag P"

# %%
ddd_p_flag_merge_fil_p.head()
# Out:
#    patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497  2748.280106                 C          O
# 1     200002  4456.162497  3983.633278                 C          O
# 2     200003  4456.162497  5918.043203                 C          O
# 3     200004  4456.162497  5882.418134                 C          O
# 4     200005  4456.162497  3519.095855                 C          O
#
#   Phone3_NBR groupid cell_flag                                 Flag
# 0          C    EarD         P  Total DDD patients with cell flag P
# 1          C    EarD         P  Total DDD patients with cell flag P
# 2          C    EarD         P  Total DDD patients with cell flag P
# 3          C    EarD         P  Total DDD patients with cell flag P
# 4          C    EarD         P  Total DDD patients with cell flag P

# %%
ddd_p_flag_merge_fil_S=ddd_p_flag_merge_fil[ddd_p_flag_merge_fil.cell_flag=="S"]

# %%
ddd_p_flag_merge_fil_S["Flag"]="Total DDD patients with cell flag S"

# %%
ddd_p_flag_merge_fil_S.head()
# Out:
# Empty DataFrame
# Columns: [patientid, membershid, person_nbr, Primary_Phone_NBR, Phone2_NBR, Phone3_NBR, groupid, cell_flag, Flag]
# Index: []

# %%
ddd_p_flag_merge_fil_N=ddd_p_flag_merge_fil[ddd_p_flag_merge_fil.cell_flag=="N"]

# %%
ddd_p_flag_merge_fil_N["Flag"]="Total DDD patients with cell flag N"
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\231835205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddd_p_flag_merge_fil_N["Flag"]="Total DDD patients with cell flag N"

# %%
ddd_p_flag_merge_fil_N.head()
# Out:
#      patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 614     200615  4456.162497  6677.313951                 O          C
# 615     200616  4456.162497  2462.055205                 O          C
# 616     200617  4456.162497  3429.345531                 O          C
# 617     200618  4456.162497  9685.907698                 O          C
# 618     200619  4456.162497  4297.300386                 O          C
#
#     Phone3_NBR groupid cell_flag                                 Flag
# 614          O    EarD         N  Total DDD patients with cell flag N
# 615          O    EarD         N  Total DDD patients with cell flag N
# 616          O    EarD         N  Total DDD patients with cell flag N
# 617          O    EarD         N  Total DDD patients with cell flag N
# 618          O    EarD         N  Total DDD patients with cell flag N

# %%
# summerise and new data frame
ddd_p_flag_merge_fil_sum=ddd_p_flag_merge_fil.groupby(["Flag"])["patientid"].count()
ddd_p_flag_merge_fil_sum_ndf=pd.DataFrame(ddd_p_flag_merge_fil_sum)
ddd_p_flag_merge_fil_sum_ndf.reset_index(inplace=True)

# %%
ddd_p_flag_merge_fil_sum_ndf
# Out:
#                  Flag  patientid
# 0  Total DDD patients      84011

# %%
ddd_p_flag_merge_fil_P_sum=ddd_p_flag_merge_fil_p.groupby(["Flag"])["patientid"].count()
ddd_p_flag_merge_fil_P_sum_ndf=pd.DataFrame(ddd_p_flag_merge_fil_P_sum)
ddd_p_flag_merge_fil_P_sum_ndf.reset_index(inplace=True)

# %%
ddd_p_flag_merge_fil_P_sum_ndf
# Out:
#                                   Flag  patientid
# 0  Total DDD patients with cell flag P      81589

# %%
ddd_p_flag_merge_fil_S_sum=ddd_p_flag_merge_fil_S.groupby(["Flag"])["patientid"].count()
ddd_p_flag_merge_fil_S_sum_ndf=pd.DataFrame(ddd_p_flag_merge_fil_S_sum)
ddd_p_flag_merge_fil_S_sum_ndf.reset_index(inplace=True)

# %%
ddd_p_flag_merge_fil_S_sum_ndf
# Out:
# Empty DataFrame
# Columns: [Flag, patientid]
# Index: []

# %%
ddd_p_flag_merge_fil_N_sum=ddd_p_flag_merge_fil_N.groupby(["Flag"])["patientid"].count()
ddd_p_flag_merge_fil_N_sum_ndf=pd.DataFrame(ddd_p_flag_merge_fil_N_sum)
ddd_p_flag_merge_fil_N_sum_ndf.reset_index(inplace=True)

# %%
ddd_p_flag_merge_fil_N_sum_ndf
# Out:
#                                   Flag  patientid
# 0  Total DDD patients with cell flag N       2422

# %%
DDD_dataframe1=pd.concat([ddd_p_flag_merge_fil_sum_ndf,ddd_p_flag_merge_fil_P_sum_ndf,ddd_p_flag_merge_fil_S_sum_ndf,ddd_p_flag_merge_fil_N_sum_ndf],axis=0,ignore_index=True)

# %%
DDD_dataframe1
# Out:
#                                   Flag  patientid
# 0                   Total DDD patients      84011
# 1  Total DDD patients with cell flag P      81589
# 2  Total DDD patients with cell flag N       2422

# %%
DDD_dataframe1.columns=["Flag","Count"]

# %%
DDD_dataframe1
# Out:
#                                   Flag  Count
# 0                   Total DDD patients  84011
# 1  Total DDD patients with cell flag P  81589
# 2  Total DDD patients with cell flag N   2422

# %%
# date
from datetime import date
date=date.today()
print(date)
# Out:
# 2023-11-10

# %%
import time
today=time.localtime()
t=time.strftime("%H:%M:%S",today)
print(t)
# Out:
# 00:42:23

# %%
DDD_dataframe1["Date"]=date

# %%
DDD_dataframe1["Time"]=t

# %%
DDD_dataframe1
# Out:
#                                   Flag  Count        Date      Time
# 0                   Total DDD patients  84011  2023-11-10  00:42:23
# 1  Total DDD patients with cell flag P  81589  2023-11-10  00:42:23
# 2  Total DDD patients with cell flag N   2422  2023-11-10  00:42:23

# %%
#ddd patients and address left merge with 3 columns
ddd_P_A_merge=DDD_patients_df.merge(DDD_add_df,how="left",on=["patientid","membershid","groupid"])
ddd_P_A_merge
# Out:
#        patientid    membershid  groupid  person_nbr_x  person_nbr_y  \
# 0         200001   4456.162497      100   2748.280106   2748.280106
# 1         200002   4456.162497      100   3983.633278   3983.633278
# 2         200003   4456.162497      100   5918.043203   5918.043203
# 3         200004   4456.162497      100   5882.418134   5882.418134
# 4         200005   4456.162497      100   3519.095855   3519.095855
# ...          ...           ...      ...           ...           ...
# 84006     284007  61967.640577      108   6406.791285   6406.791285
# 84007     284008  61967.640577      108   5736.801838   5736.801838
# 84008     284009  61967.640577      108   7613.994822   7613.994822
# 84009     284010  61967.640577      108   8530.577571   8530.577571
# 84010     284011  61967.640577      108   2140.830791   2140.830791
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR
# 0                     C          O          C
# 1                     C          O          C
# ...

# %%
ddd_P_A_merge_F=ddd_P_A_merge.merge(DDD_flag_df,how="left",on="groupid")

# %%
ddd_P_A_merge_F
# Out:
#        patientid    membershid  groupid  person_nbr_x  person_nbr_y  \
# 0         200001   4456.162497      100   2748.280106   2748.280106
# 1         200002   4456.162497      100   3983.633278   3983.633278
# 2         200003   4456.162497      100   5918.043203   5918.043203
# 3         200004   4456.162497      100   5882.418134   5882.418134
# 4         200005   4456.162497      100   3519.095855   3519.095855
# ...          ...           ...      ...           ...           ...
# 84006     284007  61967.640577      108   6406.791285   6406.791285
# 84007     284008  61967.640577      108   5736.801838   5736.801838
# 84008     284009  61967.640577      108   7613.994822   7613.994822
# 84009     284010  61967.640577      108   8530.577571   8530.577571
# 84010     284011  61967.640577      108   2140.830791   2140.830791
#
#       Primary_Phone_NBR Phone2_NBR Phone3_NBR        Flag
# 0                     C          O          C        EarD
# ...

# %%
ddd_P_A_merge_F.columns
# Out:
# Index(['patientid', 'membershid', 'groupid', 'person_nbr_x', 'person_nbr_y',
#        'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR', 'Flag'],
#       dtype='object')

# %%
#columns filter
ddd_P_A_merge_Flag=ddd_P_A_merge_F[['patientid', 'membershid',  'person_nbr_x', 
       'Primary_Phone_NBR', 'Phone2_NBR', 'Phone3_NBR','Flag' ]]

# %%
ddd_P_A_merge_Flag.head()
# Out:
#    patientid   membershid  person_nbr_x Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497   2748.280106                 C          O
# 1     200002  4456.162497   3983.633278                 C          O
# 2     200003  4456.162497   5918.043203                 C          O
# 3     200004  4456.162497   5882.418134                 C          O
# 4     200005  4456.162497   3519.095855                 C          O
#
#   Phone3_NBR  Flag
# 0          C  EarD
# 1          C  EarD
# 2          C  EarD
# 3          C  EarD
# 4          C  EarD

# %%
ddd_P_A_merge_Flag.columns
# Out:
# Index(['patientid', 'membershid', 'person_nbr_x', 'Primary_Phone_NBR',
#        'Phone2_NBR', 'Phone3_NBR', 'Flag'],
#       dtype='object')

# %%
ddd_P_A_merge_Flag.columns=['patientid', 'membershid', 'person_nbr', 'Primary_Phone_NBR',
       'Phone2_NBR', 'Phone3_NBR', 'groupid']

# %%
ddd_P_A_merge_Flag.head()
# Out:
#    patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497  2748.280106                 C          O
# 1     200002  4456.162497  3983.633278                 C          O
# 2     200003  4456.162497  5918.043203                 C          O
# 3     200004  4456.162497  5882.418134                 C          O
# 4     200005  4456.162497  3519.095855                 C          O
#
#   Phone3_NBR groupid
# 0          C    EarD
# 1          C    EarD
# 2          C    EarD
# 3          C    EarD
# 4          C    EarD

# %%
ddd_P_A_merge_Flag["cell_flag"]=""
ddd_P_A_merge_Flag.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\621940282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddd_P_A_merge_Flag["cell_flag"]=""
#    patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497  2748.280106                 C          O
# 1     200002  4456.162497  3983.633278                 C          O
# 2     200003  4456.162497  5918.043203                 C          O
# 3     200004  4456.162497  5882.418134                 C          O
# 4     200005  4456.162497  3519.095855                 C          O
#
#   Phone3_NBR groupid cell_flag
# 0          C    EarD
# 1          C    EarD
# 2          C    EarD
# 3          C    EarD
# 4          C    EarD

# %%
ddd_P_A_merge_Flag.columns
# Out:
# Index(['patientid', 'membershid', 'person_nbr', 'Primary_Phone_NBR',
#        'Phone2_NBR', 'Phone3_NBR', 'groupid', 'cell_flag'],
#       dtype='object')

# %%
ddd_P_A_merge_Flag["cell_flag"]=np.where(ddd_P_A_merge_Flag["Primary_Phone_NBR"]=="C","P",ddd_P_A_merge_Flag["cell_flag"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\1337957154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddd_P_A_merge_Flag["cell_flag"]=np.where(ddd_P_A_merge_Flag["Primary_Phone_NBR"]=="C","P",ddd_P_A_merge_Flag["cell_flag"])

# %%
ddd_P_A_merge_Flag.head()
# Out:
#    patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497  2748.280106                 C          O
# 1     200002  4456.162497  3983.633278                 C          O
# 2     200003  4456.162497  5918.043203                 C          O
# 3     200004  4456.162497  5882.418134                 C          O
# 4     200005  4456.162497  3519.095855                 C          O
#
#   Phone3_NBR groupid cell_flag
# 0          C    EarD         P
# 1          C    EarD         P
# 2          C    EarD         P
# 3          C    EarD         P
# 4          C    EarD         P

# %%
ddd_P_A_merge_Flag.cell_flag.unique()
# Out:
# array(['P', ''], dtype=object)

# %%
ddd_P_A_merge_Flag["cell_flag"]=np.where((ddd_P_A_merge_Flag["Primary_Phone_NBR"]!="C")&(ddd_P_A_merge_Flag["Phone2_NBR"]=="C"),"S",ddd_P_A_merge_Flag["cell_flag"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\1053703095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddd_P_A_merge_Flag["cell_flag"]=np.where((ddd_P_A_merge_Flag["Primary_Phone_NBR"]!="C")&(ddd_P_A_merge_Flag["Phone2_NBR"]=="C"),"S",ddd_P_A_merge_Flag["cell_flag"])

# %%
ddd_P_A_merge_Flag.cell_flag.unique()
# Out:
# array(['P', 'S', ''], dtype=object)

# %%
ddd_P_A_merge_Flag["cell_flag"]=np.where((ddd_P_A_merge_Flag["Primary_Phone_NBR"]!="C")&(ddd_P_A_merge_Flag["Phone3_NBR"]=="C"),"S",ddd_P_A_merge_Flag["cell_flag"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\1254903034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddd_P_A_merge_Flag["cell_flag"]=np.where((ddd_P_A_merge_Flag["Primary_Phone_NBR"]!="C")&(ddd_P_A_merge_Flag["Phone3_NBR"]=="C"),"S",ddd_P_A_merge_Flag["cell_flag"])

# %%
ddd_P_A_merge_Flag.cell_flag.unique()
# Out:
# array(['P', 'S', ''], dtype=object)

# %%
ddd_P_A_merge_Flag["cell_flag"]=np.where((ddd_P_A_merge_Flag["Primary_Phone_NBR"]!="C")&(ddd_P_A_merge_Flag["Phone2_NBR"]!="C"),"N",ddd_P_A_merge_Flag["cell_flag"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\4067415752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddd_P_A_merge_Flag["cell_flag"]=np.where((ddd_P_A_merge_Flag["Primary_Phone_NBR"]!="C")&(ddd_P_A_merge_Flag["Phone2_NBR"]!="C"),"N",ddd_P_A_merge_Flag["cell_flag"])

# %%
ddd_P_A_merge_Flag.cell_flag.unique()
# Out:
# array(['P', 'S', 'N'], dtype=object)

# %%
ddd_P_A_merge_Flag["cell_flag"]=np.where((ddd_P_A_merge_Flag["Primary_Phone_NBR"]!="C")&(ddd_P_A_merge_Flag["Phone3_NBR"]!="C"),"N",ddd_P_A_merge_Flag["cell_flag"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\1853137985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddd_P_A_merge_Flag["cell_flag"]=np.where((ddd_P_A_merge_Flag["Primary_Phone_NBR"]!="C")&(ddd_P_A_merge_Flag["Phone3_NBR"]!="C"),"N",ddd_P_A_merge_Flag["cell_flag"])

# %%
ddd_P_A_merge_Flag.cell_flag.unique()
# Out:
# array(['P', 'N'], dtype=object)

# %%
ddd_P_A_merge_Flag.cell_flag.value_counts()
# Out:
# P    81589
# N     2422
# Name: cell_flag, dtype: int64

# %%
# total ddd patients in cell flag P
ddd_P_A_merge_Flag["Flag"]="Toatal DDD patients"

# %%
ddd_P_A_merge_Flag.head()
# Out:
#    patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497  2748.280106                 C          O
# 1     200002  4456.162497  3983.633278                 C          O
# 2     200003  4456.162497  5918.043203                 C          O
# 3     200004  4456.162497  5882.418134                 C          O
# 4     200005  4456.162497  3519.095855                 C          O
#
#   Phone3_NBR groupid cell_flag                 Flag
# 0          C    EarD         P  Toatal DDD patients
# 1          C    EarD         P  Toatal DDD patients
# 2          C    EarD         P  Toatal DDD patients
# 3          C    EarD         P  Toatal DDD patients
# 4          C    EarD         P  Toatal DDD patients

# %%
ddd_P_A_merge_Flag_P=ddd_P_A_merge_Flag[ddd_P_A_merge_Flag.cell_flag=="P"]

# %%
ddd_P_A_merge_Flag_P["Flag"]="Total DDD patients with cell_flag P "
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\4057458342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddd_P_A_merge_Flag_P["Flag"]="Total DDD patients with cell_flag P "

# %%
ddd_P_A_merge_Flag_P.head()
# Out:
#    patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 0     200001  4456.162497  2748.280106                 C          O
# 1     200002  4456.162497  3983.633278                 C          O
# 2     200003  4456.162497  5918.043203                 C          O
# 3     200004  4456.162497  5882.418134                 C          O
# 4     200005  4456.162497  3519.095855                 C          O
#
#   Phone3_NBR groupid cell_flag                                  Flag
# 0          C    EarD         P  Total DDD patients with cell_flag P
# 1          C    EarD         P  Total DDD patients with cell_flag P
# 2          C    EarD         P  Total DDD patients with cell_flag P
# 3          C    EarD         P  Total DDD patients with cell_flag P
# 4          C    EarD         P  Total DDD patients with cell_flag P

# %%
ddd_P_A_merge_Flag_S=ddd_P_A_merge_Flag[ddd_P_A_merge_Flag.cell_flag=="S"]

# %%
ddd_P_A_merge_Flag_S["Flag"]="Total DDD patients with cell_flag S"

# %%
ddd_P_A_merge_Flag_S
# Out:
# Empty DataFrame
# Columns: [patientid, membershid, person_nbr, Primary_Phone_NBR, Phone2_NBR, Phone3_NBR, groupid, cell_flag, Flag]
# Index: []

# %%
ddd_P_A_merge_Flag_N=ddd_P_A_merge_Flag[ddd_P_A_merge_Flag.cell_flag=="N"]

# %%
ddd_P_A_merge_Flag_N["Flag"]="Total DDD patients with cell flag N"
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10648\1373899611.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ddd_P_A_merge_Flag_N["Flag"]="Total DDD patients with cell flag N"

# %%
ddd_P_A_merge_Flag_N.head()
# Out:
#      patientid   membershid   person_nbr Primary_Phone_NBR Phone2_NBR  \
# 614     200615  4456.162497  6677.313951                 O          C
# 615     200616  4456.162497  2462.055205                 O          C
# 616     200617  4456.162497  3429.345531                 O          C
# 617     200618  4456.162497  9685.907698                 O          C
# 618     200619  4456.162497  4297.300386                 O          C
#
#     Phone3_NBR groupid cell_flag                                 Flag
# 614          O    EarD         N  Total DDD patients with cell flag N
# 615          O    EarD         N  Total DDD patients with cell flag N
# 616          O    EarD         N  Total DDD patients with cell flag N
# 617          O    EarD         N  Total DDD patients with cell flag N
# 618          O    EarD         N  Total DDD patients with cell flag N

# %%
# summerise and new dataframe
ddd_P_A_merge_Flag_sum=ddd_P_A_merge_Flag.groupby(["Flag"])["patientid"].count()
ddd_P_A_merge_Flag_sum_ndf=pd.DataFrame(ddd_P_A_merge_Flag_sum)
ddd_P_A_merge_Flag_sum_ndf.reset_index(inplace=True)

# %%
ddd_P_A_merge_Flag_sum_ndf
# Out:
#                   Flag  patientid
# 0  Toatal DDD patients      84011

# %%
ddd_P_A_merge_Flag_P_sum=ddd_P_A_merge_Flag_P.groupby(["Flag"])["patientid"].count()
ddd_P_A_merge_Flag_P_sum_ndf=pd.DataFrame(ddd_P_A_merge_Flag_P_sum)
ddd_P_A_merge_Flag_P_sum_ndf.reset_index(inplace=True)

# %%
ddd_P_A_merge_Flag_P_sum_ndf
# Out:
#                                    Flag  patientid
# 0  Total DDD patients with cell_flag P       81589

# %%
ddd_P_A_merge_Flag_S_sum=ddd_P_A_merge_Flag_S.groupby(["Flag"])["patientid"].count()
ddd_P_A_merge_Flag_S_sum_ndf=pd.DataFrame(ddd_P_A_merge_Flag_S_sum)
ddd_P_A_merge_Flag_S_sum_ndf.reset_index(inplace=True)

# %%
ddd_P_A_merge_Flag_S_sum_ndf
# Out:
# Empty DataFrame
# Columns: [Flag, patientid]
# Index: []

# %%
ddd_P_A_merge_Flag_N_sum=ddd_P_A_merge_Flag_N.groupby(["Flag"])["patientid"].count()
ddd_P_A_merge_Flag_N_sum_ndf=pd.DataFrame(ddd_P_A_merge_Flag_N_sum)
ddd_P_A_merge_Flag_N_sum_ndf.reset_index(inplace=True)

# %%
ddd_P_A_merge_Flag_N_sum_ndf
# Out:
#                                   Flag  patientid
# 0  Total DDD patients with cell flag N       2422

# %%
#append
DDD_dataframe2=pd.concat([ddd_P_A_merge_Flag_sum_ndf,ddd_P_A_merge_Flag_P_sum_ndf,ddd_P_A_merge_Flag_S_sum_ndf,ddd_P_A_merge_Flag_N_sum_ndf],axis=0,ignore_index=True)

# %%
DDD_dataframe2.columns=["Flag","Count"]

# %%
DDD_dataframe2
# Out:
#                                    Flag  Count
# 0                   Toatal DDD patients  84011
# 1  Total DDD patients with cell_flag P   81589
# 2   Total DDD patients with cell flag N   2422

# %%
DDD_dataframe2["Date"]=date

# %%
DDD_dataframe2["Time"]=t

# %%
DDD_dataframe2
# Out:
#                                    Flag  Count        Date      Time
# 0                   Toatal DDD patients  84011  2023-11-10  00:42:23
# 1  Total DDD patients with cell_flag P   81589  2023-11-10  00:42:23
# 2   Total DDD patients with cell flag N   2422  2023-11-10  00:42:23

# %%
# date
from datetime import date
date=date.today()
print(date)
# Out:
# 2023-11-10

# %%
import time
today=time.localtime()
t=time.strftime("%H:%M:%S",today)
print(t)
# Out:
# 00:42:25

# %%
#append df_1,df_2,df_3,df_4
final_dataframe=pd.concat([dataframe1,dataframe2,DDD_dataframe1,DDD_dataframe2],axis=0,ignore_index=True)

# %%
final_dataframe
# Out:
#                                     Flag  Count        Date      Time
# 0                     Total BBB patients  10119  2023-11-10  00:42:08
# 1   total BBB patients with cell_Flag p    3747  2023-11-10  00:42:08
# 2    total BBB patients with cell_Flag S      1  2023-11-10  00:42:08
# 3    total BBB patients with cell_Flag N   6371  2023-11-10  00:42:08
# 4                    Total BBB patients   10119  2023-11-10  00:42:08
# 5    Total BBB patients with cell_Flag P   3747  2023-11-10  00:42:08
# 6    Total BBB patients with cell_Flag S      1  2023-11-10  00:42:08
# 7   Total BBB patients with cell_Flag N    6371  2023-11-10  00:42:08
# 8                     Total DDD patients  84011  2023-11-10  00:42:23
# 9    Total DDD patients with cell flag P  81589  2023-11-10  00:42:23
# 10   Total DDD patients with cell flag N   2422  2023-11-10  00:42:23
# 11                   Toatal DDD patients  84011  2023-11-10  00:42:23
# ...

# %%
first_column=final_dataframe.pop('Date')
final_dataframe.insert(0, 'Date',first_column )

# %%
second_column=final_dataframe.pop('Time')
final_dataframe.insert(0, 'Time',second_column )

# %%
final_dataframe
# Out:
#         Time        Date                                  Flag  Count
# 0   00:42:08  2023-11-10                    Total BBB patients  10119
# 1   00:42:08  2023-11-10  total BBB patients with cell_Flag p    3747
# 2   00:42:08  2023-11-10   total BBB patients with cell_Flag S      1
# 3   00:42:08  2023-11-10   total BBB patients with cell_Flag N   6371
# 4   00:42:08  2023-11-10                   Total BBB patients   10119
# 5   00:42:08  2023-11-10   Total BBB patients with cell_Flag P   3747
# 6   00:42:08  2023-11-10   Total BBB patients with cell_Flag S      1
# 7   00:42:08  2023-11-10  Total BBB patients with cell_Flag N    6371
# 8   00:42:23  2023-11-10                    Total DDD patients  84011
# 9   00:42:23  2023-11-10   Total DDD patients with cell flag P  81589
# 10  00:42:23  2023-11-10   Total DDD patients with cell flag N   2422
# 11  00:42:23  2023-11-10                   Toatal DDD patients  84011
# ...

# %%
final_dataframe[0:1]
# Out:
#        Time        Date                Flag  Count
# 0  00:42:08  2023-11-10  Total BBB patients  10119

# %%
final_dataframe[3:4]
# Out:
#        Time        Date                                 Flag  Count
# 3  00:42:08  2023-11-10  total BBB patients with cell_Flag N   6371
