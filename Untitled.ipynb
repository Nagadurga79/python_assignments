# %%
import pandas as pd

# %%
DOD_df=pd.read_excel(r"E:\durga79\dod_table.xlsx",sheet_name="DOD_TABLE")

# %%
DOD_df
# Out:
#     ADJUD_GROUP_OPERATIONAL_ID  CLIENT_MEMBERSHIP_ID  PERSON_NBR   PATIENT_ID  \
# 0              TXS000000287353             284208601           1  558.212.241
# 1              TXS000000287351             603035600           1  558.212.486
# 2              TXS000000287353             163012102           1  558.212.108
# 3              TXS000000287350             910656100           1  558.231.583
# 4              TXS000000287350             888543900           1  558.212.781
# ..                         ...                   ...         ...          ...
# 207            TXS000000287353              65417302           1  558.212.624
# 208            TXS000000287351             729398600           1  558.212.813
# 209            TXS000000287351             924501500           1  558.212.805
# 210            TXS000000287350             914439101           1  558.212.813
# 211            TXS000000287354             729398600           1  558.212.805
#
# ...

# %%
HIST_PHARMACY_CLAIM_DOD_ACC_SQL=""

# %%
HIST_PHARMACY_CLAIM_DOD_ACC_COL=["ADJUD_GROUP_OPERATIONAL_ID",
                                "CLIENT_MEMBERSHIP_ID","PERSON_NBR",
                                "PATIENT_ID","CARRIER_OPERATIONAL_ID",
                                "CONTRACT_OPERATIONAL_ID","PHCY_PRODUCT_SERVICE_ID",
                                "PHCY_CLAIM_ID","PHCY_RX_NBR","FILL_DAYS_SUPPLY_QTY",
                                "TRANSACTION_TYPE_CDE","MAIL_RETAIL_CDE",
                                "SERVICED_DTE","COPAY_COST_TIER_SEQ",
                                "FILL_DRUG_FORMULARY_IND","MAIL_SERVICE_RX_SRC_CDE",
                                "MAIL_SERVICE_RX_NBR","COPY_PRICING_SUB_OPTION_NBR",
                                "CLAIMS_SUBMISSION_TYPE_CDE","INTERVENTION_RULE_ID",
                                "CLIENT_GUARANTEE_CDE","MAIL_PRODUCT_SERVICE_ID",
                                "UMBRELLA_PRODUCT_ID","UMBRELLA_PRODUCT_SRC_CDE",
                                 "ELIG_GROUP_OPERATIONAL_ID",
                                "MAIL_PHCY_CDE","MAIL_PHCY_FILL_NBR",
                                "PHCY_ACCOUNT_NBR","DEA_CDE","fill_phcy_provider_id",
                                "fill_phcy_provider_src_cde","prescriber_provider_id",
                                "prescriber_provider_src_cde","Service_msg_product_id",
                                "Service_msg_product_src_cde","Billing_DAW_cde","Bil_product_service_id"]

# %%
DOD_df.columns=HIST_PHARMACY_CLAIM_DOD_ACC_COL

# %%
DOD_df.shape
# Out:
# (212, 37)

# %%
len(HIST_PHARMACY_CLAIM_DOD_ACC_COL)
# Out:
# 37

# %%
#import MPC WORK table

# %%
MEDICAL_PRODUCT_CURRENT=pd.read_excel(r"C:\Users\hp\Downloads\InputFiles.xlsx",sheet_name="MEDICAL_PRODUCT_CURRENT")

# %%
MEDICAL_PRODUCT_CURRENT
# Out:
#      PRODUCT_SERVICE_ID    EFF_DTE                 BRAND_NME  \
# 0                 10001 2021-09-04                 CAPTOPRIL
# 1                 10002 2021-09-04  SUPERMAN EXTRA VITAMIN C
# 2                 10003 2021-09-04                CLONAZEPAM
# 3                 10004 2021-09-04           BUPIVACAINE HCL
# 4                 10005 2021-09-04                  INOSITOL
# ..                  ...        ...                       ...
# 141               10142 2012-09-04           BUPIVACAINE HCL
# 142               10143 2012-09-04                  INOSITOL
# 143               10144 2012-09-04                  NYSTATIN
# 144               10145 2012-09-04                 CAPTOPRIL
# 145               10146 2012-09-04  SUPERMAN EXTRA VITAMIN C
#
#      MAINTENANCE_DRUG_CDE  SPECIALTY_PHCY_IND DRUG_SUBSTITUTION_CDE  GCN_NBR  \
# 0                       1                 NaN                     G    10482
# ...

# %%
MEDICAL_PRODUCT_CURRENT_WORK_SQL=""

# %%
MEDICAL_PRODUCT_CURRENT_WORK_COL=["PRODUCT_SERVICE_ID",
                                  "EFF_DTE","BRAND_NME",
                                  "MAINTENANCE_DRUG_CDE",
                                  "SPECIALTY_PHCY_IND",
                                  "DRUG_SUBSTITUTION_CDE",
                                  "GCN_NBR","STRENGTH_DSC",
                                  "DOSAGE_FORM_CDE","MULTI_SRC_CDE",
                                  "STRENGTH_MSR","END_EFF_DTE",
                                  "SK_STC_CDE","SK_HICL_CDE",
                                  "LABLE_TXT","MEDCO_DRUG_NBR",
                                  "DEA_CDE","LONGTERM_ACUTE"]

# %%
#MEDICAL_PRODUCT_CURRENT_WORK=pd.read_sql(MEDICAL_PRODUCT_CURRENT_WORK_SQL,connection_string)
MEDICAL_PRODUCT_CURRENT.columns=MEDICAL_PRODUCT_CURRENT_WORK_COL

# %%
MEDICAL_PRODUCT_CURRENT.shape
# Out:
# (146, 18)

# %%
len(MEDICAL_PRODUCT_CURRENT_WORK_COL)
# Out:
# 18

# %%
#import OTH table

# %%
OTH_TABLE=pd.read_excel(r"C:\Users\hp\Downloads\OTH_table.xlsx")

# %%
OTH_TABLE
# Out:
#     ADJUD_GROUP_OPERATIONAL_ID  CLIENT_MEMBERSHIP_ID  PERSON_NBR  \
# 0                      VERN045          170372685716         NaN
# 1               UFTWFINSERVICE             117364036         NaN
# 2                      VERS007          116700403601         NaN
# 3               UFTWFINSERVICE             128733635         NaN
# 4               UFTWFINSERVICE             753660753         NaN
# ..                         ...                   ...         ...
# 218               BSX3EXXXXXXX             527356605         NaN
# 219               BSX3EXXXXXXX             527356605         NaN
# 220                    VERN045             769183805         NaN
# 221             UFTWFINSERVICE             667747966         NaN
# 222                    VERS007             667747966         NaN
#
#        PATIENT_ID  CARRIER_OPERATIONAL_ID CONTRACT_OPERATIONAL_ID  \
# 0      30.714.147                    2368                   40920
# ...

# %%
HIST_PHARMACY_CLAIM_OTH_ACC_SQL=""

# %%
HIST_PHARMACY_CLAIM_OTH_ACC_COL=["ADJUD_GROUP_OPERATIONAL_ID",
                                "CLIENT_MEMBERSHIP_ID","PERSON_NBR",
                                 "PATIENT_ID","CARRIER_OPERATIONAL_ID",
                                "CONTRACT_OPERATIONAL_ID",
                                 "PHCY_PRODUCT_SERVICE_ID",
                                "PHCY_CLAIM_ID","PHCY_RX_NBR",
                                "FILL_DAYS_SUPPLY_QTY","TRANSACTION_TYPE_CDE",
                                "MAIL_RETAIL_CDE",
                                "SERVICED_DTE","COPY_COST_TIER_SEQ",
                                "FILL_DRUG_FORMULARY_IND",
                                "MAIL_SERVICE_RX_SRC_CDE","MAIL_SERVICE_RX_NBR",
                                "COPY_PRICING_SUB_OPTION_NBR",
                                "CLAIMS_SUBMISSION_TYPE_CDE",
                                "INTERVENTION_RULE_ID","CLIENT_GUARANTEE_CDE",
                                "MAIL_PRODUCT_SERVICE_ID",
                                "UMBRELLA_PRODUCT_ID","UMBRELLA_PRODUCT_SRC_CDE",
                                "ELIG_GROUP_OPERATIONAL_ID","MAIL_PHCY_CDE",
                                "MAIL_PHCY_FILL_NBR",
                                "PHCY_ACCOUNT_NBR","DEA_CDE","fill_phcy_provider_id",
                                "fill_phcy_provider_src_cde","prescriber_provider_id",
                                "prescriber_provider_src_cde","Service_msg_product_id",
                                "Service_msg_product_src_cde","Billing_DAW_cde",
                                "Bil_product_service_id"]

# %%
OTH_TABLE.columns=HIST_PHARMACY_CLAIM_OTH_ACC_COL

# %%
OTH_TABLE.shape
# Out:
# (223, 37)

# %%
len(HIST_PHARMACY_CLAIM_OTH_ACC_COL)
# Out:
# 37

# %%
MEDB_OPPORTUNITY_M=MEDB_OPPORTUNITY.merge(MEMBER_CURRENT,how='inner',on=["patient_id","group_operational_id"])

# %%
MEDB_OPPORTUNITY_DOD_M=MEDB_OPPORTUNITY.merge(MEDB_OPPORTUNITY_DOD,how-"inner",on=["patient_id","group_operational_id"])

# %%
name="ravi"

# %%
print( "hi" + name)
# Out:
# hiravi
