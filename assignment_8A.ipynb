# %%
import pandas as pd

# %%
df2=pd.read_csv(r"E:\durga79\friendnames,quality.txt",header="infer")
df2
# Out:
#   friendnames          quality
# 0        vani   always_smiling
# 1      ayesha   always_smiling
# 2      anusha      very_simple
# 3      akhila         talktive
# 4     supraja         talktive
# 5       manoj    always_joking
# 6     harsahd    always_joking
# 7        arif      intelligent
# 8        ajay  always_smiling

# %%
import pandas as pd

# %%
pd.read_csv(r"E:\durga79\familymember_namerelation.txt",sep="*",header="infer")
# Out:
#   familymember_name        relation
# 0           baburao          father
# 1      dhanalakshmi          mother
# 2          srinivas         brother
# 3           sravani          sister
# 4            kumari           pinni
# 5       yedukondalu           babai
# 6          gayathri  younger_sister
# 7             radha           pinni
# 8             durga    grand_mother
# 9          subbarao    grand_father

# %%
import pandas as pd

# %%
pd.read_csv(r"E:\durga79\vegfood.txt",sep="|",header="infer")
# Out:
#    vegfood_names         taste
# 0   pappu_tomato         tasty
# 1         omblet         spicy
# 2  pulihora_sour           NaN
# 3         pongal         sweet
# 4          semya         sweet
# 5         burelu  sweetandsalt
# 6        ariselu         sweet
# 7      halwapuri         sweet
# 8         samosa         spicy
# 9     badam_milk          cool

# %%
import pandas as pd

# %%
pd.read_csv(r"E:\durga79\nonveg.txt",sep="|",header="infer")
# Out:
#           nonveg_food            taste
# 0             biryani  spicy_and_tasty
# 1   chicken_friedrice  spicy_and_tasty
# 2              omblet  spicy_and_salty
# 3     chicken_lolipop            spicy
# 4  chicken_manchuriya            spicy
# 5             fishfry            spicy
# 6           prawnsfry            spicy
# 7     grilled_chicken            spicy

# %%
import pandas as pd

# %%
pd.read_csv(r"E:\durga79\months.txt",sep="&",header="infer")
# Out:
#    month_name        season
# 0     january        winter
# 1    february        winter
# 2       march        summer
# 3       april        summer
# 4         may        summer
# 5        june        summer
# 6        july  rainy_season
# 7      august  rainy_season
# 8   september  rainy_season
# 9     october        winter
# 10   november        winter
# 11   december        winter

# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\durga79\colournames.txt",sep="^",header="infer")

# %%
df
# Out:
#   colourname_english colourname_hindi colourname_telugu
# 0                red             laal             arupu
# 1              green             hara            pachha
# 2              black            kaala            nalupu
# 3               blue            neela            neelam
# 4             yellow            peela            pasupu
# 5              white            safed           thelupu
# 6             orange         naaramgi          kashayam
# 7               pink           gulabi            gulabi
# 8          navi_blue      gahar_neela            neelam
# 9           sky_blue          phiroja      light_neelam

# %%
df.head(10)
# Out:
#   colourname_english colourname_hindi colourname_telugu
# 0                red             laal             arupu
# 1              green             hara            pachha
# 2              black            kaala            nalupu
# 3               blue            neela            neelam
# 4             yellow            peela            pasupu
# 5              white            safed           thelupu
# 6             orange         naaramgi          kashayam
# 7               pink           gulabi            gulabi
# 8          navi_blue      gahar_neela            neelam
# 9           sky_blue          phiroja      light_neelam

# %%
df.tail(3)
# Out:
#   colourname_english colourname_hindi colourname_telugu
# 7               pink           gulabi            gulabi
# 8          navi_blue      gahar_neela            neelam
# 9           sky_blue          phiroja      light_neelam

# %%
df.columns
# Out:
# Index(['colourname_english', 'colourname_hindi', 'colourname_telugu'], dtype='object')

# %%
df.dtypes
# Out:
# colourname_english    object
# colourname_hindi      object
# colourname_telugu     object
# dtype: object

# %%
df.shape
# Out:
# (10, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   colourname_english  10 non-null     object
#  1   colourname_hindi    10 non-null     object
#  2   colourname_telugu   10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.iloc[0:5,0:2]
# Out:
#   colourname_english colourname_hindi
# 0                red             laal
# 1              green             hara
# 2              black            kaala
# 3               blue            neela
# 4             yellow            peela

# %%
df_fil=df[(df["colourname_english"]=="green")|(df["colourname_english"]=="yellow")]

# %%
df_fil
# Out:
#   colourname_english colourname_hindi colourname_telugu
# 1              green             hara            pachha
# 4             yellow            peela            pasupu

# %%
append=pd.concat([df,df2])

# %%
append
# Out:
#   colourname_english colourname_hindi colourname_telugu friendnames  \
# 0                red             laal             arupu         NaN
# 1              green             hara            pachha         NaN
# 2              black            kaala            nalupu         NaN
# 3               blue            neela            neelam         NaN
# 4             yellow            peela            pasupu         NaN
# 5              white            safed           thelupu         NaN
# 6             orange         naaramgi          kashayam         NaN
# 7               pink           gulabi            gulabi         NaN
# 8          navi_blue      gahar_neela            neelam         NaN
# 9           sky_blue          phiroja      light_neelam         NaN
# 0                NaN              NaN               NaN        vani
# 1                NaN              NaN               NaN      ayesha
# 2                NaN              NaN               NaN      anusha
# ...
